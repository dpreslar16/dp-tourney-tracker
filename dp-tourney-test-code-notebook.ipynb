# %%
print('Participant Menu \n================ \n1. Sign Up \n2. Cancel Sign Up \n3. View Participants\n4. Save Changes\n5. Exit')
main_menu_input = str(input("What is thy bidding my master?")).lower()
if main_menu_input in ['1', '1.', '1. sign up', 'sign up']:
    #Sign Up code
    print('hey')
# Out:
# Participant Menu
# ================
# 1. Sign Up
# 2. Cancel Sign Up
# 3. View Participants
# 4. Save Changes
# 5. Exit
# hey

# %%
slot_entry = 8
print(isinstance(slot_entry, int))
# Out:
# True

# %%
num_part = 50
dict_part = {
    1: "Luke Skywalker",
    2: "Ahsoka Tano",
    43: "Din Djarin"
}
print('Participant Sign Up\n===================\n')
part_name = str(input('Participant Name: '))
slot_entry = input('Desired starting slot #[1-' + str(num_part) + "]: ")
while isinstance(slot_entry, int) == False  or slot_entry > num_part or slot_entry < 1:
    try:
        slot_entry = int(slot_entry)
        print(slot_entry in dict_part.keys())
        if slot_entry in dict_part.keys():
            slot_entry = input("Error:\nSlot #" + str(slot_entry) + " is filled. Please try again.\n\nDesired starting slot#[1-" + str(num_part) + "]: ")
            continue
        elif slot_entry < num_part + 1 and slot_entry > 0:
            dict_part[slot_entry] = part_name
            print("Success:\n" + part_name + " is signed up in starting slot #" + str(slot_entry))
            break
        else:
            slot_entry = input("Please enter the participant's desired starting slot as an integer between 1 and " + str(num_part) + '.')
    except:
        slot_entry = input("Please enter the participant's desired starting slot as an integer between 1 and " + str(num_part) + '.')


print(dict_part)
# Out:
# Participant Sign Up
# ===================
#
# True
# False
# False
# False
# Success:
# Darth Vader is signed up in starting slot #3
# {1: 'Luke Skywalker', 2: 'Ahsoka Tano', 43: 'Din Djarin', 3: 'Darth Vader'}

# %%
num_part = 50
dict_part = {
    1: "Luke Skywalker",
    2: "Ahsoka Tano",
    43: "Din Djarin"
}
print('Participant Sign Up\n===================\n')
part_name = 'Darth Vader'
slot_entry = 2
try:
    slot_entry = int(slot_entry)
    print(slot_entry in dict_part.keys())
    if slot_entry in dict_part.keys():
        slot_entry = input("Error:\nSlot #" + slot_entry + " is filled. Please try again.\n\nDesired starting slot#[1-" + str(num_part) + "]: ")
        print("1")
    elif slot_entry < num_part + 1 and slot_entry > 0:
        dict_part[slot_entry] = part_name
        print("Success:\n" + part_name + " is signed up in starting slot #" + str(slot_entry))
        print('2')
    else:
        slot_entry = input("Please enter the participant's desired starting slot as an integer between 1 and " + str(num_part) + '.')
        print('3')
except:
    slot_entry = input("Please enter the participant's desired starting slot as an integer between 1 and " + str(num_part) + '.')


print(dict_part)
# Out:
# Participant Sign Up
# ===================
#
# True
# {1: 'Luke Skywalker', 2: 'Ahsoka Tano', 43: 'Din Djarin'}

# %%
int('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4036/1136785238.py in <module>
# ----> 1 int('hello')
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
num_part = 50
dict_part = {
    1: "Luke Skywalker",
    2: "Ahsoka Tano",
    43: "Din Djarin"
}
print('Participant Sign Up\n===================\n')
part_name = str(input('Participant Name: '))
slot_entry = input('Desired starting slot #[1-' + str(num_part) + "]: ")
end_loop = 1
print(dict_part.keys())
while end_loop == 1:
    try:
        slot_entry = int(slot_entry)
        break
    except:
        slot_entry = input("Please enter the participant's desired starting slot as an integer between 1 and " + str(num_part) + '.')

if slot_entry in dict_part.keys():
    slot_entry = input("Error:\nSlot #" + str(slot_entry) + " is filled. Please try again.\n\nDesired starting slot#[1-" + str(num_part) + "]: ")
elif slot_entry < num_part + 1 and slot_entry > 0:
    dict_part[slot_entry] = part_name
    print("Success:\n" + part_name + " is signed up in starting slot #" + str(slot_entry))
else:
    slot_entry = input("Please enter the participant's desired starting slot as an integer between 1 and " + str(num_part) + '.')

print(dict_part)
# Out:
# Participant Sign Up
# ===================
#
# dict_keys([1, 2, 43])
# {1: 'Luke Skywalker', 2: 'Ahsoka Tano', 43: 'Din Djarin'}
